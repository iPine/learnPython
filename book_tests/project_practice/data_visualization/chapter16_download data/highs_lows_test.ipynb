# %%
from highs_lows_visual import HighsLowsVisual
from readfile_function import read_file

# %matplotlib inline

filename1 = 'death_valley_2014.csv'
filename2 = 'sitka_weather_2014.csv'

dates1,highs1,lows1 = read_file(filename1)
test1 = HighsLowsVisual(dates1,highs1,lows1)
test1.highs_lows_visual()

dates2,highs2,lows2 = read_file(filename2)
test2 = HighsLowsVisual(dates2,highs2,lows2)
test2.highs_lows_visual()
# Out:
# 2014-02-16 00:00:00 missing data
