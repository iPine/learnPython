# %%
import csv

import pygal_maps_world.maps
from pygal.style import RotateStyle as RS, LightColorizedStyle as LCS
from itertools import islice 

from country_codes import get_country_code

# import numpy as np
# from matplotlib import pyplot as plt

filename = 'children_out_of_school_primary_female.csv'

"""从文件中读取国家、辍学人数"""
cc_num = []
with open(filename, encoding='gb18030', errors='ignore') as f:
    outschool_data = csv.reader(f)
    print(outschool_data)
    
    country_num = {}
    # 打印每个国家2010年的gdp
    for row in islice(outschool_data,5,None):
#         print(row)
#         print(row[0])
        try:
            country_num[row[0]] = int(row[60])
        except ValueError:
            print('missing data')
    print(country_num.keys())
    
    cc_num = {}
    for country_name in country_num.keys():
        code = get_country_code(country_name)
        print(code)
        if code:
            for number in country_num.values():
                    cc_num[code] = number
    print(cc_num)
    
    wm_style = RS('#664477',base_style=LCS)
    #创建了一个 Worldmap 实例
    wm = pygal_maps_world.maps.World(style=wm_style)
    wm.title = 'Female children out of Primary School in 2016, by Country'
  
    wm.add('2016',cc_num)
    wm.render_to_file('fechildren_out_of_primaryschool.svg')
# Out:
# <_csv.reader object at 0x0000014302FD13F0>
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# missing data
# dict_keys(['Albania', 'Arab World', 'United Arab Emirates', 'Armenia', 'Australia', 'Azerbaijan', 'Burkina Faso', 'Bulgaria', 'Bahrain', 'Bahamas, The', 'Belarus', 'Belize', 'Bolivia', 'Barbados', 'Brunei Darussalam', 'Bhutan', 'Central Europe and the Baltics', 'Switzerland', 'Chile', "Cote d'Ivoire", 'Cameroon', 'Colombia', 'Cabo Verde', 'Costa Rica', 'Djibouti', 'Dominica', 'Denmark', 'Dominican Republic', 'Algeria', 'East Asia & Pacific (excluding high income)', 'Early-demographic dividend', 'East Asia & Pacific', 'Europe & Central Asia (excluding high income)', 'Europe & Central Asia', 'Ecuador', 'Egypt, Arab Rep.', 'Euro area', 'Spain', 'European Union', 'Finland', 'Ghana', 'Gambia, The', 'Grenada', 'Guatemala', 'High income', 'Hong Kong SAR, China', 'Honduras', 'Heavily indebted poor countries (HIPC)', 'Croatia', 'Hungary', 'IBRD only', 'IDA & IBRD total', 'IDA total', 'IDA blend', 'Indonesia', 'IDA only', 'Israel', 'Kazakhstan', 'Kyrgyz Republic', 'Cambodia', 'Kuwait', 'Latin America & Caribbean (excluding high income)', 'Lao PDR', 'Lebanon', 'Latin America & Caribbean', 'Least developed countries: UN classification', 'Low income', 'Lower middle income', 'Low & middle income', 'Lesotho', 'Late-demographic dividend', 'Lithuania', 'Macao SAR, China', 'Morocco', 'Maldives', 'Middle East & North Africa', 'Mexico', 'Marshall Islands', 'Middle income', 'Mali', 'Middle East & North Africa (excluding high income)', 'Montenegro', 'Mongolia', 'Mauritania', 'Mauritius', 'Malaysia', 'North America', 'Niger', 'Netherlands', 'Norway', 'Nepal', 'Nauru', 'New Zealand', 'OECD members', 'Oman', 'Other small states', 'Pakistan', 'Peru', 'Poland', 'Pre-demographic dividend', 'Portugal', 'West Bank and Gaza', 'Pacific island small states', 'Post-demographic dividend', 'Qatar', 'Romania', 'Russian Federation', 'Rwanda', 'South Asia', 'Senegal', 'Solomon Islands', 'Sierra Leone', 'El Salvador', 'Serbia', 'Sub-Saharan Africa (excluding high income)', 'Sub-Saharan Africa', 'Small states', 'Suriname', 'East Asia & Pacific (IDA & IBRD countries)', 'Europe & Central Asia (IDA & IBRD countries)', 'Togo', 'Tajikistan', 'Latin America & the Caribbean (IDA & IBRD countries)', 'Timor-Leste', 'Middle East & North Africa (IDA & IBRD countries)', 'South Asia (IDA & IBRD)', 'Sub-Saharan Africa (IDA & IBRD countries)', 'Upper middle income', 'Uzbekistan', 'St. Vincent and the Grenadines', 'Venezuela, RB', 'World', 'Samoa', 'Yemen, Rep.'])
# al
# None
# ae
# am
# au
# az
# bf
# bg
# bh
# None
# by
# bz
# None
# None
# bn
# bt
# None
# ch
# cl
# ci
# cm
# co
# None
# cr
# dj
# None
# dk
# do
# dz
# None
# None
# None
# None
# None
# ec
# None
# None
# es
# None
# fi
# gh
# None
# None
# gt
# None
# None
# hn
# None
# hr
# hu
# None
# None
# None
# None
# id
# None
# il
# kz
# None
# kh
# kw
# None
# None
# lb
# None
# None
# None
# None
# None
# ls
# None
# lt
# None
# ma
# mv
# None
# mx
# None
# None
# ml
# None
# me
# mn
# mr
# mu
# my
# None
# ne
# nl
# no
# np
# None
# nz
# None
# om
# None
# pk
# pe
# pl
# None
# pt
# None
# None
# None
# None
# ro
# ru
# rw
# None
# sn
# None
# sl
# sv
# rs
# None
# None
# None
# sr
# None
# None
# tg
# tj
# None
# tl
# None
# None
# None
# None
# uz
# None
# None
# None
# None
# None
# {'al': 456088, 'ae': 456088, 'am': 456088, 'au': 456088, 'az': 456088, 'bf': 456088, 'bg': 456088, 'bh': 456088, 'by': 456088, 'bz': 456088, 'bn': 456088, 'bt': 456088, 'ch': 456088, 'cl': 456088, 'ci': 456088, 'cm': 456088, 'co': 456088, 'cr': 456088, 'dj': 456088, 'dk': 456088, 'do': 456088, 'dz': 456088, 'ec': 456088, 'es': 456088, 'fi': 456088, 'gh': 456088, 'gt': 456088, 'hn': 456088, 'hr': 456088, 'hu': 456088, 'id': 456088, 'il': 456088, 'kz': 456088, 'kh': 456088, 'kw': 456088, 'lb': 456088, 'ls': 456088, 'lt': 456088, 'ma': 456088, 'mv': 456088, 'mx': 456088, 'ml': 456088, 'me': 456088, 'mn': 456088, 'mr': 456088, 'mu': 456088, 'my': 456088, 'ne': 456088, 'nl': 456088, 'no': 456088, 'np': 456088, 'nz': 456088, 'om': 456088, 'pk': 456088, 'pe': 456088, 'pl': 456088, 'pt': 456088, 'ro': 456088, 'ru': 456088, 'rw': 456088, 'sn': 456088, 'sl': 456088, 'sv': 456088, 'rs': 456088, 'sr': 456088, 'tg': 456088, 'tj': 456088, 'tl': 456088, 'uz': 456088}
