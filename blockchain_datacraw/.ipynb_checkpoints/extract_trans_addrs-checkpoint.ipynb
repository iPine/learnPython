# %%
"""从区块数据中提取每个区块内的交易数据，以及交易数据涉及到的所有地址"""
import json
import format_transaction as ft
import json


def load_trans(transdata):
    """
    将格式好的交易数据存入transactions.json文件；
    因为每个区块内的交易是一个列表，为了让所有区块的交易以字典结构存到一个文件，就需要一笔一笔写入文件
    """
    with open('transactions.json','a') as f:
        for line in transdata:
            f.write(json.dumps(line,ensure_ascii=False,indent=2 )) 
            f.write(',')

def load_addrs(address):
    """
    将提取的所有交易地址存入address.json文件；
    """
    #必须以'a'方式写，不然只会存入最后一个区块的交易涉及的地址
    with open('address.json','a') as f:
        for line in address:
            f.write('{"address":[')
            f.write(json.dumps(line,ensure_ascii=False,indent=2 ) + '\n')
            f.write(',')
            f.write(']}')


        
def getblockhash_height(url,height=''):
    """从抓取的区块高度和区块哈希文件中单独提取出哈希值和高度"""
   
    with open(url,'r') as f:
        lines = json.loads(f.read())
        block= []
        for line in reversed(lines[:-5]):
            if height:
                block.append(line['height'])
            else:
                block.append(line['hash'])
        return block

def main():
    #blockheight = 532365
    #blockhash = "000000000000000000317d0ec9a48c7debd7a4d5010c087850a47c5d9f605da9"
    #blocks_height = [height for height in range(532365,532425)]
    #blocks_height = sorted(blocks_height,reverse = True)
    blocks_hash= getblockhash_height('height_hash.json')
    blocks_height = getblockhash_height('height_hash.json',True)
    #print(blocks_hash)
    #print(blocks_height)

    while blocks_height:
        #pop()删除后还能使用
        blockheight = blocks_height.pop()
        blockhash = blocks_hash.pop()
    #    print(blockheight)
    #    print(blockhash)
        url = 'blockdata/blcokheight_' + str(blockheight) + '.json'
        print(url)
    # 根据flag来判断，提取的是交易信息还是地址信息
    #     transdata = ft.format_transaction(url,blockheight,blockhash,flag=0)
    #     print(transdata)
    #     load_trans(transdata)

        addrs = ft.format_transaction(url,blockheight,blockhash)
        print(len(addrs))
        print(addrs)
        load_addrs(addrs)
# Out:
# blockdata/blcokheight_532365.json
# 2
# [{'addr': '1EVzaFkkNNXq6RJh2oywwJMn8JPiq8ikDi'}, {'addr': '3B8PuYQbBaYvuQW3dPvxn8E8bmKBXTiTuC'}]
# blockdata/blcokheight_532366.json
# 2
# [{'addr': '3JJfSJGBpTnaibi58ZPKxSL5xozQqLVSRA'}, {'addr': '1Nt25cWEWCiLUDTz6eABWXKpztxaUJrLZN'}]
# blockdata/blcokheight_532367.json
# 2
# [{'addr': '1C1mCxRukix1KfegAY5zQQJV7samAciZpv'}, {'addr': '3PrMAah5GZUuk5r8xmnb3aaVywxfmeku4k'}]
# blockdata/blcokheight_532368.json
# 2
# [{'addr': '1C1mCxRukix1KfegAY5zQQJV7samAciZpv'}, {'addr': '124JUvqYXtgptRRdeAgvYtNemnBbuGDa23'}]
# blockdata/blcokheight_532369.json
# 2
# [{'addr': '1Nh7uHdvY6fNwtQtM1G5EZAFPLC33B59rB'}, {'addr': '1HYBBj9Ckkz5yH6zboNrXa3RDx9iYUzwqS'}]
# blockdata/blcokheight_532370.json
# 2
# [{'addr': '1KFHE7w8BhaENAswwryaoccDb6qcT6DbYY'}, {'addr': '1KFHE7w8BhaENAswwryaoccDb6qcT6DbYY'}]
# blockdata/blcokheight_532371.json
# 2
# [{'addr': '1C1mCxRukix1KfegAY5zQQJV7samAciZpv'}, {'addr': 'bc1qj3uzc87u6r898glc73jlg7e4yp2mmtrfj64aq3'}]
# blockdata/blcokheight_532372.json
# 2
# [{'addr': '1C1mCxRukix1KfegAY5zQQJV7samAciZpv'}, {'addr': '14eeBATgjCxz5XmWkbwtXC5LCH44aT76vx'}]
# blockdata/blcokheight_532373.json
# 2
# [{'addr': '1CK6KHY6MHgYvmRQ4PAafKYDrg1ejbH1cE'}, {'addr': '18x5Wo3FLQN4t1DLZgV2MoAMWXmCYL9b7M'}]
# blockdata/blcokheight_532374.json
# 2
# [{'addr': '18cBEMRxXHqzWWCxZNtU91F5sbUNKhL5PX'}, {'addr': '13gWBMA8ecgNerppFSGYR5EMeCrWwacd6e'}]
# blockdata/blcokheight_532375.json
# 2
# [{'addr': '1C1mCxRukix1KfegAY5zQQJV7samAciZpv'}, {'addr': '19pMmfy354Bxji2rgkMryUqyjeDoCE2Lhz'}]
# blockdata/blcokheight_532376.json
# 2
# [{'addr': '1GbukP5VhUUfoZs3bGPzsjHMuNUvwsYk9Q'}, {'addr': '14nX91o89Go8vnnE231KjMGM5pBmZKNZPq'}]
# blockdata/blcokheight_532377.json
# 2
# [{'addr': '13hQVEstgo4iPQZv9C7VELnLWF7UWtF4Q3'}, {'addr': '1APBBoNmhPewsdFzQQWP3qCo4VXwe5tJqJ'}]
# blockdata/blcokheight_532378.json
# 2
# [{'addr': '1KCm3E97dedS2xGCPNh5oo7Rx8cUk8jvMn'}, {'addr': '131NvF3VsM54NQgTpKD7mi7ySwvqgxxCjz'}]
# blockdata/blcokheight_532379.json
# 2
# [{'addr': '1Nh7uHdvY6fNwtQtM1G5EZAFPLC33B59rB'}, {'addr': '1B5W2rxx48mikXQL3ELeC1jmQip7Q6x4kb'}]
# blockdata/blcokheight_532380.json
# 2
# [{'addr': '18cBEMRxXHqzWWCxZNtU91F5sbUNKhL5PX'}, {'addr': '16V5G4BYrWZTuenTEYnEWRDqDhoPW3Xzf2'}]
# blockdata/blcokheight_532381.json
# 2
# [{'addr': '1C1mCxRukix1KfegAY5zQQJV7samAciZpv'}, {'addr': '39Yt5YdkPsAdMw9USzKai29fAqgphUsyxS'}]
# blockdata/blcokheight_532382.json
# 2
# [{'addr': '3KJrsjfg1dD6CrsTeHdHVH3KqMpvL2XWQn'}, {'addr': '13TwysAQvTaGeopF71xDJDdpYp8Y97nTkK'}]
# blockdata/blcokheight_532383.json
# 1
# [{'addr': '1KCm3E97dedS2xGCPNh5oo7Rx8cUk8jvMn'}]
# blockdata/blcokheight_532384.json
# 2
# [{'addr': '165GCEAx81wce33FWEnPCRhdjcXCrBJdKn'}, {'addr': '12pTc7twZ2T1BHv4zJHHSpHQn7XLUivMx4'}]
# blockdata/blcokheight_532385.json
# 1
# [{'addr': '1C1mCxRukix1KfegAY5zQQJV7samAciZpv'}]
# blockdata/blcokheight_532386.json
# 1
# [{'addr': '1C1mCxRukix1KfegAY5zQQJV7samAciZpv'}]
# blockdata/blcokheight_532387.json
# 2
# [{'addr': '1Nh7uHdvY6fNwtQtM1G5EZAFPLC33B59rB'}, {'addr': '1GeWi7CpNhGSs9GdUk1aes3cYf9uej2pJK'}]
# blockdata/blcokheight_532388.json
# 2
# [{'addr': '1Nh7uHdvY6fNwtQtM1G5EZAFPLC33B59rB'}, {'addr': '3EMhnuJisGgDTJ9HiQhZ68Cb6dZ2NYtoCN'}]
# blockdata/blcokheight_532389.json
# 2
# [{'addr': '13hQVEstgo4iPQZv9C7VELnLWF7UWtF4Q3'}, {'addr': '3N3C4vDE9XHESpYFYYwDXkGiDunRYshr6G'}]
# blockdata/blcokheight_532390.json
# 2
# [{'addr': '1KFHE7w8BhaENAswwryaoccDb6qcT6DbYY'}, {'addr': '3Fj75jr1V2AiSr9nzaCuLzU9JHdVxf7qVm'}]
# blockdata/blcokheight_532391.json
# 2
# [{'addr': '1Hz96kJKF2HLPGY15JWLB5m9qGNxvt8tHJ'}, {'addr': '3DL4CmZcvj4iKertAenGzK5mie64ndFs1p'}]
# blockdata/blcokheight_532392.json
# 2
# [{'addr': '18cBEMRxXHqzWWCxZNtU91F5sbUNKhL5PX'}, {'addr': '3PBjYay4i5cfymFasLxXyoaxaUgN7yLzEE'}]
# blockdata/blcokheight_532393.json
# 2
# [{'addr': '1Nh7uHdvY6fNwtQtM1G5EZAFPLC33B59rB'}, {'addr': '17A16QmavnUfCW11DAApiJxp7ARnxN5pGX'}]
# blockdata/blcokheight_532394.json
# 2
# [{'addr': '1C1mCxRukix1KfegAY5zQQJV7samAciZpv'}, {'addr': '1ASaVfbBA39MBkRgzXsqKYsfQ3mmfsX8zP'}]
# blockdata/blcokheight_532395.json
# 2
# [{'addr': '18cBEMRxXHqzWWCxZNtU91F5sbUNKhL5PX'}, {'addr': '1H3byXbarLfGuHk3FVqh8AQFbYBAJDmNJK'}]
# blockdata/blcokheight_532396.json
# 2
# [{'addr': '1KFHE7w8BhaENAswwryaoccDb6qcT6DbYY'}, {'addr': '34YugGncAb8gBRkiWkFyCXbwrV56jtc4H9'}]
# blockdata/blcokheight_532397.json
# 2
# [{'addr': '18cBEMRxXHqzWWCxZNtU91F5sbUNKhL5PX'}, {'addr': '1LmjfhrnJcq9Te3h7x7cDQcXPneqS1jTJc'}]
# blockdata/blcokheight_532398.json
# 2
# [{'addr': '3KJrsjfg1dD6CrsTeHdHVH3KqMpvL2XWQn'}, {'addr': '12eVjvt9W3aKAj6yBrmzD1Ru8yKpyQMexw'}]
# blockdata/blcokheight_532399.json
# 2
# [{'addr': '1C1mCxRukix1KfegAY5zQQJV7samAciZpv'}, {'addr': '3NphQqmRgkNyjdRjmKd2HfwVZrEh3aPZje'}]
# blockdata/blcokheight_532400.json
# 2
# [{'addr': '3KJrsjfg1dD6CrsTeHdHVH3KqMpvL2XWQn'}, {'addr': '3ADZ3ZU5s4A3UxvduduPDx4fJtwaHMpW9x'}]
# blockdata/blcokheight_532401.json
# 2
# [{'addr': '1CK6KHY6MHgYvmRQ4PAafKYDrg1ejbH1cE'}, {'addr': '1DQmzZPkdVGyKJrEdp72ko5kXTQD1gjRuD'}]
# blockdata/blcokheight_532402.json
# 2
# [{'addr': '3KJrsjfg1dD6CrsTeHdHVH3KqMpvL2XWQn'}, {'addr': '19n24VTXg9KNW2rj2QrMAkH6kjHiBp4U6D'}]
# blockdata/blcokheight_532403.json
# 2
# [{'addr': '1Hz96kJKF2HLPGY15JWLB5m9qGNxvt8tHJ'}, {'addr': 'bc1qwqdg6squsna38e46795at95yu9atm8azzmyvckulcc7kytlcckxswvvzej'}]
# blockdata/blcokheight_532404.json
# 2
# [{'addr': '1CK6KHY6MHgYvmRQ4PAafKYDrg1ejbH1cE'}, {'addr': '1FytYtJ48WUm11CVwj5CizUm4fQxmKZqpB'}]
# blockdata/blcokheight_532405.json
# 2
# [{'addr': '1KCm3E97dedS2xGCPNh5oo7Rx8cUk8jvMn'}, {'addr': '1JDknRvZTi5XdhQB3cgvJ9R8aogUvfbYUB'}]
# blockdata/blcokheight_532406.json
# 2
# [{'addr': '18cBEMRxXHqzWWCxZNtU91F5sbUNKhL5PX'}, {'addr': '1H5F1FPKK2R1mzfHTJib7yqNhRoEt9KZyW'}]
# blockdata/blcokheight_532407.json
# 2
# [{'addr': '1C1mCxRukix1KfegAY5zQQJV7samAciZpv'}, {'addr': '1CpDqQSts3yg7rXWkyMCxDfWg2yXDZwPyB'}]
# blockdata/blcokheight_532408.json
# 2
# [{'addr': '1CK6KHY6MHgYvmRQ4PAafKYDrg1ejbH1cE'}, {'addr': '32RLpxyCB2VacC243TAupxTLkV5fQGtta7'}]
# blockdata/blcokheight_532409.json
# 2
# [{'addr': '1C1mCxRukix1KfegAY5zQQJV7samAciZpv'}, {'addr': '3E62zzQYjZDJQYWCvhPiJhacrz7pvXVdLu'}]
# blockdata/blcokheight_532410.json
# 2
# [{'addr': '1KFHE7w8BhaENAswwryaoccDb6qcT6DbYY'}, {'addr': '3AxHFZ2ivJUBgveyNj1PQak6FsKBcLJ42N'}]
# blockdata/blcokheight_532411.json
# 2
# [{'addr': '1C1mCxRukix1KfegAY5zQQJV7samAciZpv'}, {'addr': 'bc1qwqdg6squsna38e46795at95yu9atm8azzmyvckulcc7kytlcckxswvvzej'}]
# blockdata/blcokheight_532412.json
# 2
# [{'addr': '1Nh7uHdvY6fNwtQtM1G5EZAFPLC33B59rB'}, {'addr': '3BMEX4JJFaZtVSDkLUvXKTtc6GUYmYyEhh'}]
# blockdata/blcokheight_532413.json
# 2
# [{'addr': '1C1mCxRukix1KfegAY5zQQJV7samAciZpv'}, {'addr': '1J1kkynuRyYpd2iMQU6EKtoScyoRpWxvfn'}]
# blockdata/blcokheight_532414.json
# 2
# [{'addr': '1Nh7uHdvY6fNwtQtM1G5EZAFPLC33B59rB'}, {'addr': '1A2zvHVZH3JofeDDKy27fyAQs4Zy8ACADj'}]
# blockdata/blcokheight_532415.json
# 2
# [{'addr': '1Hz96kJKF2HLPGY15JWLB5m9qGNxvt8tHJ'}, {'addr': '1CTEyVwUZbNtRQS5wbPP4ydbqjJCEWUiwH'}]
# blockdata/blcokheight_532416.json
# 2
# [{'addr': '1CK6KHY6MHgYvmRQ4PAafKYDrg1ejbH1cE'}, {'addr': '15XMrYCxybxyfT8aQE5wJkCiyUAsXvVLjx'}]
# blockdata/blcokheight_532417.json
# 2
# [{'addr': '1KFHE7w8BhaENAswwryaoccDb6qcT6DbYY'}, {'addr': '1Z6bgHBqs5wumMZaPLiZQrRmbBpeATApY'}]
# blockdata/blcokheight_532418.json
# 2
# [{'addr': '1Hz96kJKF2HLPGY15JWLB5m9qGNxvt8tHJ'}, {'addr': '1DTm1DipgYM8bWJ3gqQ5dzDb1N56xDtTyZ'}]
# blockdata/blcokheight_532419.json
# 2
# [{'addr': '1Nh7uHdvY6fNwtQtM1G5EZAFPLC33B59rB'}, {'addr': '1DnADS6pu3sHVXGK8bc8ny2Do1jLvFtTn8'}]
# blockdata/blcokheight_532420.json
# 2
# [{'addr': '1Hz96kJKF2HLPGY15JWLB5m9qGNxvt8tHJ'}, {'addr': 'bc1qwqdg6squsna38e46795at95yu9atm8azzmyvckulcc7kytlcckxswvvzej'}]
# blockdata/blcokheight_532421.json
# 2
# [{'addr': '1C1mCxRukix1KfegAY5zQQJV7samAciZpv'}, {'addr': '14mS1U5KCtm7k8pFRpjAs3sSFJkQNSZGgt'}]
# blockdata/blcokheight_532422.json
# 2
# [{'addr': '1C1mCxRukix1KfegAY5zQQJV7samAciZpv'}, {'addr': '1DM9qqUWD358uaUHqFhD1Fpr36eUgDbWmE'}]
# blockdata/blcokheight_532423.json
# 2
# [{'addr': '1CK6KHY6MHgYvmRQ4PAafKYDrg1ejbH1cE'}, {'addr': '3FqrKwMxuSJZuzXRnkidMaNBxCgKjaVsnB'}]
# blockdata/blcokheight_532424.json
# 2
# [{'addr': '1C1mCxRukix1KfegAY5zQQJV7samAciZpv'}, {'addr': '339eNPWmsH249BTjCzGtgGXtNQz8G2nwbb'}]
# blockdata/blcokheight_532425.json
# 2
# [{'addr': '1RtUKxMRGBrz7Qt3YPZJb988PddKCNEFk'}, {'addr': '1AtHDAdBEw6bUtnjYQbbYjVKvSmRrdmomY'}]
